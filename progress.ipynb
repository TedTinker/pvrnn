# %%
import os
import shutil
from time import sleep
from linecache import getline
from IPython.display import clear_output



class File:
    
    def __init__(self, file_name):
        self.delete_me = False
        self.file_name = file_name
        file_name, suffix = file_name.split(".")
        if(suffix != "out"): self.delete_me = True ; return
        self.slurm_name = file_name.split("_")[0]
            
        self.name_for_user = "Starting..."
        lines = open(self.file_name).readlines()
        for i, line in enumerate(lines):
            if(line[:5] == "name:" and lines[i+1][0] != "\t"):
                self.name_for_user = lines[i+1][:-1]
                break
        
        self.last_line = "Starting..."
        if(len(lines) != 0):
            last = -1
            while(lines[last] == "\n"): last -= 1
            self.last_line = lines[last]
            
    def done(self):
        if(self.last_line.endswith("Done!\n")): return(True)
        return(False)
        
    def __lt__(self, other): return(self.slurm_name < other.slurm_name)
            
    

first = True
while(True):
    file_names = [f for f in os.listdir() if f[:5]=="slurm"]
    
    files = []
    for name in file_names:
        file = File(name)
        if(file.delete_me): pass 
        else:               files.append(file)
    files.sort()

    ongoing = []              ; finished = []
    
    for file in files:
        done = file.done() 
        if(done): finished.append(file)
        else:     ongoing.append(file)
    
    if(not first):
        print("\n\n")
        for i in range(10):
            print(i+1, end = "... ")
            sleep(1)
    first = False
    
    clear_output(wait=True)
    
    max_len = max([len("{} ({}):".format(file.name_for_user, file.file_name)) for file in ongoing + finished]) + 1
    print("Ongoing:")
    if(len(ongoing) == 0): print("None.")
    for file in ongoing: 
        last_line = file.last_line if file.last_line[-1] != "\n" else file.last_line[:-1]
        string = "{} ({}):".format(file.name_for_user, file.file_name)
        while(len(string) < max_len): string += " "
        print(string + last_line)

    print("\n\n\nFinished:")
    if(len(finished) == 0): print("None.")
    else:
        for i, file in enumerate(finished):
            last_line = file.last_line if file.last_line[-1] != "\n" else file.last_line[:-1]
            string = "{} ({}):".format(file.name_for_user, file.file_name)
            while(len(string) < max_len): string += " "
            print(string + last_line)
# Out:
# Ongoing:
# plotting (slurm-31248414.out):               pvrnn/plotting.py:37: RuntimeWarning: divide by zero encountered in log
#
#
#
# Finished:
# d_hard (slurm-31248376.out):                 Duration: 0:20:11. Done!
# d_hard (slurm-31248377.out):                 Duration: 0:20:35. Done!
# d_hard (slurm-31248378.out):                 Duration: 0:17:37. Done!
# d_hard_rand (slurm-31248379.out):            Duration: 0:17:05. Done!
# d_hard_rand (slurm-31248380.out):            Duration: 0:18:28. Done!
# d_hard_rand (slurm-31248381.out):            Duration: 0:18:39. Done!
# e_hard (slurm-31248382.out):                 Duration: 0:20:38. Done!
# e_hard (slurm-31248383.out):                 Duration: 0:20:29. Done!
# e_hard (slurm-31248384.out):                 Duration: 0:19:33. Done!
# e_hard_rand (slurm-31248385.out):            Duration: 0:19:36. Done!
# e_hard_rand (slurm-31248386.out):            Duration: 0:19:34. Done!
# e_hard_rand (slurm-31248387.out):            Duration: 0:19:18. Done!
# n_hard (slurm-31248388.out):                 Duration: 0:20:22. Done!
# n_hard (slurm-31248389.out):                 Duration: 0:20:37. Done!
# n_hard (slurm-31248390.out):                 Duration: 0:17:56. Done!
# n_hard_rand (slurm-31248391.out):            Duration: 0:18:13. Done!
# n_hard_rand (slurm-31248392.out):            Duration: 0:22:23. Done!
# n_hard_rand (slurm-31248393.out):            Duration: 0:22:21. Done!
# en_hard (slurm-31248394.out):                Duration: 0:23:23. Done!
# en_hard (slurm-31248395.out):                Duration: 0:21:36. Done!
# en_hard (slurm-31248396.out):                Duration: 0:21:33. Done!
# en_hard_rand (slurm-31248397.out):           Duration: 0:21:38. Done!
# en_hard_rand (slurm-31248398.out):           Duration: 0:22:18. Done!
# en_hard_rand (slurm-31248399.out):           Duration: 0:22:32. Done!
# f_hard (slurm-31248401.out):                 Duration: 0:21:04. Done!
# f_hard (slurm-31248402.out):                 Duration: 0:21:26. Done!
# f_hard (slurm-31248403.out):                 Duration: 0:20:46. Done!
# f_hard_rand (slurm-31248404.out):            Duration: 0:20:44. Done!
# f_hard_rand (slurm-31248405.out):            Duration: 0:20:15. Done!
# f_hard_rand (slurm-31248406.out):            Duration: 0:20:06. Done!
# ef_hard (slurm-31248407.out):                Duration: 0:21:48. Done!
# ef_hard (slurm-31248408.out):                Duration: 0:21:44. Done!
# ef_hard (slurm-31248409.out):                Duration: 0:21:46. Done!
# ef_hard_rand (slurm-31248410.out):           Duration: 0:21:53. Done!
# ef_hard_rand (slurm-31248411.out):           Duration: 0:18:20. Done!
# ef_hard_rand (slurm-31248412.out):           Duration: 0:18:06. Done!
# finishing_dictionaries (slurm-31248413.out): Duration: 0:00:20. Done!
# plotting_positions (slurm-31248415.out):     Duration: 0:00:46. Done!
# plotting_predictions (slurm-31248416.out):   Duration: 0:02:05. Done!
# plotting_p_values (slurm-31248417.out):      Duration: 0:00:07. Done!
# combining_plots (slurm-31248418.out):        Duration: 0:00:34. Done!
#
#
#
# 1... 2... 3... 4... 5... 6... 7... 8... 9...
